# %% [markdown]
# # Facebook Checkin Prediction
# ## Udacity Machine Learning Nanodegree Capstone Project

# %% [markdown]
# ## Data Import

# %%
# %matplotlib inline
# Import Libraries

import numpy as np
import pandas as pd

# Clear memory on initialize
test_df = None
train_df = None
train_data = None
test_data = None


# Import Data
train_data = pd.read_csv("data/train.csv")
print "Training data loaded successfully"
print len(train_data)
# Out:
# Training data loaded successfully
# 29118021

# %% [markdown]
# ## Data Formatting and Transformation

# %%
# Reduce the data to coordinate sets, minimum of 0.0 maximum of 10.0, this reduces overall working dataset size while
# maintaining neighbor relationships.

min_x = 0.0
max_x = 10.0
min_y = 0.0
max_y = 10.0

reduced_data = train_data[(train_data['x'] >= min_x) & (train_data['x'] <= max_x) & (train_data['y'] >= min_y) & (train_data['y'] <= max_y)]

# Remove csv import from Memory
train_data = None

# Cursory validation that data is imported properly
print reduced_data.head()
# Out:
#    row_id       x       y  accuracy    time    place_id
# 0       0  0.7941  9.0809        54  470702  8523065625
# 1       1  5.9567  4.7968        13  186555  1757726713
# 2       2  8.3078  7.0407        74  322648  1137537235
# 3       3  7.3665  2.5165        65  704587  6567393236
# 4       4  4.0961  1.1307        31  472130  7440663949

# %%
# split data into targets and features

training_feature_column = list(reduced_data.columns[:-1])
training_target_column = reduced_data.columns[-1]

feature_all = reduced_data[training_feature_column]
target_all = reduced_data[training_target_column]



# Change index on DataFrame
feature_df = pd.DataFrame(feature_all, index=reduced_data['row_id'], columns=['x','y','accuracy','time'])
target_df = pd.DataFrame(target_all, index=reduced_data['row_id'])


print feature_df.head()
print target_df.head()
# Out:
#              x       y  accuracy    time
# row_id
# 0       0.7941  9.0809        54  470702
# 1       5.9567  4.7968        13  186555
# 2       8.3078  7.0407        74  322648
# 3       7.3665  2.5165        65  704587
# 4       4.0961  1.1307        31  472130
#           place_id
# row_id
# 0       8523065625
# 1       1757726713
# 2       1137537235
# 3       6567393236
# 4       7440663949

# %%
#remove original import if all data formatting is complete to save memory if necessary
reduced_data = None
train_data = None
test_data = None

# %% [markdown]
# ## Statistics and Visualization
# This section will provide basic statistic and graphical representations of the data correlated to the report section of the same name.

# %% [markdown]
# ### Basic information about the dataset

# %%
# Run diagnostics after import

print "Training Data Length: " + str(len(feature_df.index))


# Basic Statistics
print "\nUnique places in training set: " + str(target_df.place_id.nunique())
print "\nUnique X coordinates in training set: " + str(feature_df.x.nunique())
print "\nMinimum and Maximum X coordiante: " + str(feature_df.x.min()) + " " + str(feature_df.x.max())
print "\nUnique Y coordinates in training set: " + str(feature_df.y.nunique())
print "\nMinimum and Maximum Y coordiante: " + str(feature_df.y.min()) + " " + str(feature_df.y.max())
print "\nUnique timestamps in training set: " + str(feature_df.time.nunique())
print "\nMinimum timestamp in training set: " + str(feature_df.time.min())
print "\nMaximum timestamp in training set: " + str(feature_df.time.max())
print "\nUnique accuracy measures in training set: " + str(feature_df.accuracy.nunique())
# Out:
# Training Data Length: 29118021
#
# Unique places in training set: 108390
#
# Unique X coordinates in training set: 100001
#
# Minimum and Maximum X coordiante: 0.0 10.0
#
# Unique Y coordinates in training set: 100001
#
# Minimum and Maximum Y coordiante: 0.0 10.0
#
# Unique timestamps in training set: 786239
#
# Minimum timestamp in training set: 1
#
# Maximum timestamp in training set: 786239
#
# Unique accuracy measures in training set: 1025

# %% [markdown]
# ### Feature reformatting
# In this section, features such as time will be reformatted to more useful formats as discussed in the associated report.
#
# In this case, the time will be reduced from completely linear, into a Day of the Week, Hour of the Day formatted as 0-6 for the day and 0-23 for the hour and split into two columns

# %%
from pandas import *
def SetDay(x):
    x = float(x)
    day_of_week = x/(60*24*7) - int(x/(60*24*7))
    day_exact = day_of_week*7
    day = int(day_exact)
    hour_exact = (day_exact - day)*24
    hour = int(hour_exact)
    return day, hour

feature_df["day"], feature_df["hour"] = zip(*feature_df["time"].map(SetDay))

print feature_df.head()
# Out:
#              x       y  accuracy    time  day  hour
# row_id
# 0       0.7941  9.0809        54  470702    4    21
# 1       5.9567  4.7968        13  186555    3    13
# 2       8.3078  7.0407        74  322648    0     1
# 3       7.3665  2.5165        65  704587    6     7
# 4       4.0961  1.1307        31  472130    5    20

# %% [markdown]
# ### Graphical Representation of the Dataset

# %%
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt


# the histogram of the data
plt.hist(feature_df['day'], 7)


plt.xlabel('day of week')
plt.ylabel('checkins')
plt.title('Check ins by day of week')
plt.axis([-1, 7, 4000000, 4500000])
plt.grid(True)
plt.show()

# %%
plt.hist(feature_df['hour'], 24)


plt.xlabel('Hour of Day')
plt.ylabel('checkins')
plt.title('Check ins by hour of day')
plt.axis([-1, 24, 1205000, 1225000])
plt.grid(True)
plt.show()

# %% [markdown]
# ### Sample data and plot in x,y space

# %%
sample_data = feature_df.sample(n=50000)
plt.figure(num=None, figsize=(10, 10), facecolor='w', edgecolor='k')
plt.scatter(sample_data["x"], sample_data["y"], marker = "o", alpha=0.1)
plt.axis([0,10,0,10])
plt.grid(True)
plt.show()

# %% [markdown]
# ### Statistical Analysis of the Dataset

# %% [markdown]
# From the previous section it is apparent that there is very little variation in checkin behavior by GPS coordinate, or by time of the day, or by day of the week. The plot of x,y data does reveal local concentrations which could be considered to be "popular" check-in spots. Since the check-in ID's are simply randomly assigned values, statistical analysis of those values would be mostly meaningless. From this point it is apparent that this is a very difficult machine learning problem with no obvious patterns or data concentrations.
#
# By my estimation, basic statistical measurements on this dataset will not reveal anything. I will proceed to the machine learning portion of this report.

# %% [markdown]
# ## Machine Learning Algorithms and Testing

# %%
## Modified Chunk of code from Brad Miller's (my) ML Nanodegree Project 2

# First, decide how many training vs test samples you want
num_all = feature_df.shape[0]  


# set testing set size in percentage
testing_set_percentage = 0.1


#set testing set size (in number of data points as a float) and the number of training sets
testing_set_size = round(num_all*testing_set_percentage)
num_training_sets = 10
training_set_total = num_all - testing_set_size
training_size_iterator = training_set_total/num_training_sets
    
from sklearn.cross_validation import train_test_split

# initiate iterator for loop
i = 1

# instantiate empty dict for data
complete_data = {}

while i <= num_training_sets:
    training_set_size = i*training_size_iterator
    X_train_iter, X_test_iter, y_train_iter, y_test_iter = train_test_split(
        feature_df, target_df, test_size=float(testing_set_size)/num_all, train_size = float(training_set_size)/num_all, random_state=41)
    
    dataset_list = [X_train_iter, y_train_iter, X_test_iter, y_test_iter]
    complete_data[str(int(training_set_size))] = dataset_list
    i+=1
    
# TODO: Then, select features (X) and corresponding labels (y) for the training and test sets
# Note: Shuffle the data or randomly select samples to avoid any bias due to ordering in the dataset
print "Training set: {} samples".format(complete_data[str(int(training_set_size))][0].shape[0])
print "Test set: {} samples".format(complete_data[str(int(training_set_size))][2].shape[0])
# Note: If you need a validation set, extract it from within training data
# Out:
# Training set: 251958 samples
# Test set: 27995 samples

# %% [markdown]
# ## Train models

# %%
# Code Sampled from Project 2
# Train a model
import time


# Training function
def train_classifier(clf, X_train, y_train):
    print "Training {}...".format(clf.__class__.__name__)
    start = time.time()
    clf.fit(X_train, y_train)
    end = time.time()
    print "Done!\nTraining time (secs): {:.3f}".format(end - start)


# NOTE FROM STUDENT: I created a loop below to go through all three models and all three training data sizes.
# The code here is to satisfy the TODO items. The code loop below is where all results used in the report are returned

# Import algorithms
from sklearn import svm
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier



clf = KNeighborsClassifier(n_neighbors=10, weights='distance')
# Fit model to training data
train_classifier(clf, complete_data[str(int(training_set_size))][0], complete_data[str(int(training_set_size))][1])  # note: using entire training set here
#print clf  # you can inspect the learned model by printing it
# Out:
# Training KNeighborsClassifier...
# Done!
# Training time (secs): 1.425
# /Library/Python/2.7/site-packages/ipykernel/__main__.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().

# %% [markdown]
# # Predict place

# %%
# Predict on training set and compute F1 score
from sklearn.metrics import f1_score

def predict_labels(clf, features, target):
    print "Predicting labels using {}...".format(clf.__class__.__name__)
    start = time.time()
    y_pred = clf.predict(features)
    end = time.time()
    print "Done!\nPrediction time (secs): {:.3f}".format(end - start)
    return f1_score(target.values, y_pred, pos_label='yes')

train_f1_score = predict_labels(clf, complete_data[str(int(training_set_size))][0], complete_data[str(int(training_set_size))][1])
print "F1 score for training set: {}".format(train_f1_score)
# Out:
# Predicting labels using KNeighborsClassifier...
# Done!
# Prediction time (secs): 133.202
# F1 score for training set: 1.0
# /Library/Python/2.7/site-packages/sklearn/metrics/classification.py:756: DeprecationWarning: The default `weighted` averaging is deprecated, and from version 0.18, use of precision, recall or F-score with multiclass or multilabel data or pos_label=None will result in an exception. Please set an explicit value for `average`, one of (None, 'micro', 'macro', 'weighted', 'samples'). In cross validation use, for instance, scoring="f1_weighted" instead of scoring="f1".
#   sample_weight=sample_weight)

# %%
# Predict on test data
print "F1 score for test set: {}".format(predict_labels(clf, complete_data[str(int(training_set_size))][2], complete_data[str(int(training_set_size))][3]))
# Out:
# Predicting labels using KNeighborsClassifier...
# Done!
# Prediction time (secs): 10.668
# F1 score for test set: 0.0605595258425
# /Library/Python/2.7/site-packages/sklearn/metrics/classification.py:756: DeprecationWarning: The default `weighted` averaging is deprecated, and from version 0.18, use of precision, recall or F-score with multiclass or multilabel data or pos_label=None will result in an exception. Please set an explicit value for `average`, one of (None, 'micro', 'macro', 'weighted', 'samples'). In cross validation use, for instance, scoring="f1_weighted" instead of scoring="f1".
#   sample_weight=sample_weight)

# %%
# Train and predict using different training set sizes
def train_predict(clf, X_train, y_train, X_test, y_test):
    print "------------------------------------------"
    print "Training set size: {}".format(len(X_train))
    train_classifier(clf, X_train, y_train)
    print "F1 score for training set: {}".format(predict_labels(clf, X_train, y_train))
    print "F1 score for test set: {}".format(predict_labels(clf, X_test, y_test))


knn = KNeighborsClassifier(n_neighbors=10, weights='distance')
gnb = GaussianNB()
support_vm = svm.SVC()
model_list = [knn, gnb, support_vm]
for model in model_list:
    for index in complete_data:
        train_predict(model, complete_data[index][0], complete_data[index][1], complete_data[index][2], complete_data[index][3])
# Out:
# ------------------------------------------
# Training set size: 25195
# Training KNeighborsClassifier...
# Done!
# Training time (secs): 0.049
# Predicting labels using KNeighborsClassifier...
# Done!
# Prediction time (secs): 4.896
# /Library/Python/2.7/site-packages/ipykernel/__main__.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# /Library/Python/2.7/site-packages/sklearn/metrics/classification.py:756: DeprecationWarning: The default `weighted` averaging is deprecated, and from version 0.18, use of precision, recall or F-score with multiclass or multilabel data or pos_label=None will result in an exception. Please set an explicit value for `average`, one of (None, 'micro', 'macro', 'weighted', 'samples'). In cross validation use, for instance, scoring="f1_weighted" instead of scoring="f1".
#   sample_weight=sample_weight)
